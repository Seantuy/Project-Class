# %%
import pandas as pd
filename="H:\Downloads\PhD.dataset.csv"
data=pd.read_csv(filename,nrows=44000,header=0)
data.head()
# Out:
#    Unnamed: 0               Auteur Identifiant auteur  \
# 0           0       Saeed Al marri                NaN
# 1           1    Andrea Ramazzotti          174423705
# 2           2  OLIVIER BODENREIDER                NaN
# 3           3       Emmanuel Porte                NaN
# 4           4     Arthur Devriendt                NaN
#
#                                                Titre  \
# 0  Le credit documentaire et l'onopposabilite des...
# 1  Application de la PGD a la resolution de probl...
# 2  Conception d'un outil informatique d'etude des...
# 3  Socio-histoire des politiques publiques en mat...
# 4  LES TECHNOLOGIES DE L'INFORMATION ET DE LA COM...
#
#                            Directeur de these  \
# 0                         Philippe Delebecque
# 1  Jean-Claude Grandidier,Marianne Beringhier
# 2                             Francois Kohler
# 3                               Gilles Pollet
# 4                               Gabriel Dupuy
#
# ...

# %%
data_subset=data[data["Genre"]=="male"]
data_subset.head(10)
# Out:
#     Unnamed: 0                  Auteur Identifiant auteur  \
# 0            0          Saeed Al marri                NaN
# 2            2     OLIVIER BODENREIDER                NaN
# 3            3          Emmanuel Porte                NaN
# 4            4        Arthur Devriendt                NaN
# 7            7  Laurent david Benoiton                NaN
# 11          11        Vladimir Arneuve                NaN
# 13          13             Ahmad Abbas                NaN
# 14          14             Luc Verrier                NaN
# 17          17     Mohammed Al khateeb                NaN
# 22          22          Walid El nabal                NaN
#
#                                                 Titre  \
# 0   Le credit documentaire et l'onopposabilite des...
# 2   Conception d'un outil informatique d'etude des...
# 3   Socio-histoire des politiques publiques en mat...
# 4   LES TECHNOLOGIES DE L'INFORMATION ET DE LA COM...
# ...

# %%
data_subset2=data[data["Genre"]=="female"]
data_subset2.head(10)
# Out:
#     Unnamed: 0                        Auteur Identifiant auteur  \
# 1            1             Andrea Ramazzotti          174423705
# 8            8  Jennifer Guiraud (McKELLIPS)                NaN
# 9            9    Nathalie Warcholak (David)                NaN
# 15          15                Elodie Demaret                NaN
# 16          16         Mariela cecilia Avila                NaN
# 18          18                  Fanny Arnaud                NaN
# 19          19              Nicole Abravanel                NaN
# 20          20        Ioana Raluca Andreescu                NaN
# 23          23                   Alda Ayessa                NaN
# 28          28          Sonia Altuna delgado                NaN
#
#                                                 Titre  \
# 1   Application de la PGD a la resolution de probl...
# 8   L'autobiographie sans frontieres : espace et d...
# 9               Interoperabilite et droits du marche.
# ...

# %%
gender=["male","female"]
gender1=["M", "F"]
data['Genre']=data['Genre'].replace(gender,gender1)
data.head()
# Out:
#    Unnamed: 0               Auteur Identifiant auteur  \
# 0           0       Saeed Al marri                NaN
# 1           1    Andrea Ramazzotti          174423705
# 2           2  OLIVIER BODENREIDER                NaN
# 3           3       Emmanuel Porte                NaN
# 4           4     Arthur Devriendt                NaN
#
#                                                Titre  \
# 0  Le credit documentaire et l'onopposabilite des...
# 1  Application de la PGD a la resolution de probl...
# 2  Conception d'un outil informatique d'etude des...
# 3  Socio-histoire des politiques publiques en mat...
# 4  LES TECHNOLOGIES DE L'INFORMATION ET DE LA COM...
#
#                            Directeur de these  \
# 0                         Philippe Delebecque
# 1  Jean-Claude Grandidier,Marianne Beringhier
# 2                             Francois Kohler
# 3                               Gilles Pollet
# 4                               Gabriel Dupuy
#
# ...

# %%
print(data["Genre"].describe())
print()
print(data.info())
print()
print(data.shape)
# Out:
# count     10000
# unique        6
# top           F
# freq       4101
# Name: Genre, dtype: object
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Unnamed: 0                                10000 non-null  int64
#  1   Auteur                                    10000 non-null  object
#  2   Identifiant auteur                        774 non-null    object
#  3   Titre                                     10000 non-null  object
#  4   Directeur de these                        10000 non-null  object
#  5   Directeur de these (nom prenom)           10000 non-null  object
#  6   Identifiant directeur                     10000 non-null  object
#  7   Etablissement de soutenance               10000 non-null  object
# ...
